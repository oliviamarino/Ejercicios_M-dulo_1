# %%
import random

# Ajustes
palabras = 'adalab lovelace mujer python analytics data bootcamp hacker'.split()

# Variables calculadas
palabra_secreta = palabras[random.randint(0, len(palabras)-1)].upper()
output = list(len(palabra_secreta)*'_')

# Strings

# Inicio del juego
Bienvenida = (" --!Comenzamos el juego!--  ")
Instrucciones = (" Tienes 8 intentos para adivinar la palabra")

# Adivinanzas

inputs = []

#Input de la usuaria

n_intentos = 0

while n_intentos < 8:

    indice_palabra = 0
    almacenar = True

    letra_introducida = (str(input("Dime una letra"))).upper()
        
    for letra in palabra_secreta:
        if letra_introducida == letra:  
            output[indice_palabra] = letra_introducida
            almacenar = False

        indice_palabra += 1

    if almacenar == True:
        inputs.append(letra_introducida)
    

    n_intentos += 1
    
    print("Intento ", n_intentos, ":", letra_introducida)
    print(''.join(output)," - ",''.join(inputs))

    if palabra_secreta == "".join(output):
        print ("--!Terminamos el juego¡--\n")
        print ("Enhorabuena, has adivinado la palabra.")
        break


if palabra_secreta != "".join(output):
        print ("--!Terminamos el juego¡--\n Lo siento, más suerte la próxima vez.!")

# %% [markdown]
# HABIENDO CON UN ELSE

# %%
import random

# Ajustes
palabras = 'adalab lovelace mujer python analytics data bootcamp hacker'.split()

# Variables calculadas
palabra_secreta = palabras[random.randint(0, len(palabras)-1)].upper()
palabra_con_guiones = list(len(palabra_secreta)*'_')

# Strings

# Inicio del juego
Bienvenida = (" --!Comenzamos el juego!--  ")
Instrucciones = (" Tienes 8 intentos para adivinar la palabra")

# Adivinanzas

letras_falladas = []

#Input de la usuaria
print(Bienvenida)
print(Instrucciones)
print(palabra_con_guiones)

n_intentos = 0

while n_intentos < 8:

    indice_palabra = 0

    letra_introducida = (str(input("Dime una letra"))).upper()
        
    for letra in palabra_secreta:
        if letra_introducida == letra:  
            palabra_con_guiones[indice_palabra] = letra_introducida
        else:
            if not letra_introducida in letras_falladas:
                letras_falladas.append(letra_introducida)

        indice_palabra += 1

    n_intentos += 1
    
    print("Intento ", n_intentos, ":", letra_introducida)
    print(' '.join(palabra_con_guiones)," - ",' '.join(letras_falladas))

    if palabra_secreta == "".join(palabra_con_guiones):
        print ("--!Terminamos el juego¡--\n")
        print ("Enhorabuena, has adivinado la palabra.")
        break

if palabra_secreta != " ".join(palabra_con_guiones):
        print ("--!Terminamos el juego¡--\n Lo siento, más suerte la próxima vez.!")

print('la palabra era', palabra_secreta)
# Out:
#  --!Comenzamos el juego!--
#  Tienes 8 intentos para adivinar la palabra
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Intento  1 : A
# A _ A _ _ _ _ _ _  -  A
# Intento  2 : E
# A _ A _ _ _ _ _ _  -  A E
# Intento  3 : O
# A _ A _ _ _ _ _ _  -  A E O
# Intento  4 : S
# A _ A _ _ _ _ _ S  -  A E O S
# Intento  5 : F
# A _ A _ _ _ _ _ S  -  A E O S F
# Intento  6 : M
# A _ A _ _ _ _ _ S  -  A E O S F M
# Intento  7 : D
# A _ A _ _ _ _ _ S  -  A E O S F M D
# Intento  8 : L
# A _ A L _ _ _ _ S  -  A E O S F M D L
# --!Terminamos el juego¡--
#  Lo siento, más suerte la próxima vez.!
# la palabra era ANALYTICS
